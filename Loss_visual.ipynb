# %%
import numpy as np
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib

# %%
data = np.load('avg_losses.npz')

x=range(len(data['L']))
y=data['L'].reshape(-1)

plt.title('last loss cost : %f' %y[-1])
plt.plot(x,y)

plt.show()

print ('average : '+str(np.average(data['L'])))
print ('min : '+str(np.min(data['L'])))
# Out:
# average : 35.91382375433524
# min : 33.851847553042184

# %%
data = np.load('NLL_losses.npz')

x=range(len(data['L']))
y=data['L'].reshape(-1)

plt.title('last loss cost : %f' %y[-1])
plt.plot(x,y)
plt.show()

print ('average : '+str(np.average(data['L'])))
print ('min : '+str(np.min(data['L'])))
# Out:
# average : 31.73879973258972
# min : 15.054521560668945

# %%
data = np.load('KL_losses.npz')

x=range(len(data['L']))
y=data['L'].reshape(-1)

plt.title('last loss cost : %f' %y[-1])
plt.plot(x,y)
plt.show()

print ('average : '+str(np.average(data['L'])))
print ('min : '+str(np.min(data['L'])))
# Out:
# average : 5.628442563018093
# min : 0.34725484251976013

# %%
data = np.load('KL_weights.npz')

x=range(len(data['L']))
y=data['L'].reshape(-1)

plt.title('last loss cost : %f' %y[-1])
plt.plot(x,y)
plt.show()

print ('average : '+str(np.average(data['L'])))
print ('min : '+str(np.min(data['L'])))
# Out:
# average : 0.7217940891518732
# min : 0.0066928509242848554
